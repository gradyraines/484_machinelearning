# %%
import statsmodels.api as sm 
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('/Users/meru1/Box/1 Research Folder/RESEARCH FOLDER/Dance With The Devil/Femicide - Consumption Stats/6_13_state_age_size_pg_5_2006_2007.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (38,78) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df = df[df['panelyear']==2006]

# %%
df['log_revenue'] = np.log10(df['pg_capital_ventas'])
df['log_totalconsumption'] = np.log10(df['gastot_g'])
df['log_personalspending'] = np.log10(df['personal_g'])
df['personalspending_pc'] = df['personal_g']/df['totalpopulation']
df['log_personalspending_pc'] = np.log10(df['personalspending_pc'])
df['totalconsump_pc'] = df['gastot_g']/df['totalpopulation']
df['log_totalconsump_pc'] = np.log10(df['totalconsump_pc'])

# %%
#FINAL RESULTS

# %%
#BELOW ARE OUR MAIN REGRESSIONS FOR THE PAPER 

#FISRT HYPOTHESIS 

#FEMICIDE TREAT LEADS TO LESS FIRM REVEUNE

X = df[['vio_treat_y','lmedian_income','border','highschoolpc',"unemploymentrate","firmage",
'pg_empleados',"total_crimepc",'innovacion','immigrantpc','selfemployedpc','totalpopulation','protestantpc',
 'zd_zona_Semiurbano',
 'zd_zona_Urbano','pg_sector_11.0',
 'pg_sector_21.0',
 'pg_sector_22.0',
 'pg_sector_23.0',
 'pg_sector_31.0',
 'pg_sector_32.0',
 'pg_sector_33.0',
 'pg_sector_43.0',
 'pg_sector_46.0',
 'pg_sector_48.0',
 'pg_sector_49.0',
 'pg_sector_51.0',
 'pg_sector_52.0',
 'pg_sector_53.0',
 'pg_sector_54.0',
 'pg_sector_55.0',
 'pg_sector_56.0',
 'pg_sector_61.0',
 'pg_sector_62.0',
 'pg_sector_71.0',
 'pg_sector_72.0',
 'pg_sector_81.0']]
Y = df['log_revenue']
model = sm.OLS(Y, X, missing='drop').fit()
results2_robust = model.get_robustcov_results()
print(results2_robust.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            log_revenue   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Mon, 28 Jun 2021   Prob (F-statistic):                nan
# Time:                        11:18:51   Log-Likelihood:                -2488.1
# No. Observations:                6013   AIC:                             5046.
# Df Residuals:                    5978   BIC:                             5281.
# Df Model:                          34
# Covariance Type:                  HC1
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# vio_treat_y           -0.0429      0.018     -2.369      0.018      -0.078      -0.007
# ...

# %%
#H2

#Local * Femicide treat is positive 

df['interaction_treat_loc'] = df['vio_treat_y']*df['ambitooperacion_loc']

X = df[['vio_treat_y','ambitooperacion_loc','interaction_treat_loc','lmedian_income','border','highschoolpc',"unemploymentrate","firmage",
'pg_empleados',"total_crimepc",'innovacion','immigrantpc','selfemployedpc','totalpopulation','protestantpc',
 'zd_zona_Semiurbano',
 'zd_zona_Urbano','pg_sector_11.0',
 'pg_sector_21.0',
 'pg_sector_22.0',
 'pg_sector_23.0',
 'pg_sector_31.0',
 'pg_sector_32.0',
 'pg_sector_33.0',
 'pg_sector_43.0',
 'pg_sector_46.0',
 'pg_sector_48.0',
 'pg_sector_49.0',
 'pg_sector_51.0',
 'pg_sector_52.0',
 'pg_sector_53.0',
 'pg_sector_54.0',
 'pg_sector_55.0',
 'pg_sector_56.0',
 'pg_sector_61.0',
 'pg_sector_62.0',
 'pg_sector_71.0',
 'pg_sector_72.0',
 'pg_sector_81.0']]
Y = df['log_revenue']
model = sm.OLS(Y, X, missing='drop').fit()
results2_robust = model.get_robustcov_results()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            log_revenue   R-squared:                       0.160
# Model:                            OLS   Adj. R-squared:                  0.155
# Method:                 Least Squares   F-statistic:                     31.56
# Date:                Mon, 28 Jun 2021   Prob (F-statistic):          1.51e-195
# Time:                        11:19:02   Log-Likelihood:                -2446.4
# No. Observations:                6013   AIC:                             4967.
# Df Residuals:                    5976   BIC:                             5215.
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# vio_treat_y              -0.2038      0.054     -3.784      0.000      -0.309      -0.098
# ...

# %%
#BELOW IS THE Mediation  

#FINAL

#model 1 

#treat on rev


X = df[['vio_treat_y','lmedian_income','border','highschoolpc',"unemploymentrate","firmage",
'pg_empleados',"total_crimepc",'innovacion','immigrantpc','selfemployedpc','totalpopulation','protestantpc',
 'zd_zona_Semiurbano',
 'zd_zona_Urbano','pg_sector_11.0',
 'pg_sector_21.0',
 'pg_sector_22.0',
 'pg_sector_23.0',
 'pg_sector_31.0',
 'pg_sector_32.0',
 'pg_sector_33.0',
 'pg_sector_43.0',
 'pg_sector_46.0',
 'pg_sector_48.0',
 'pg_sector_49.0',
 'pg_sector_51.0',
 'pg_sector_52.0',
 'pg_sector_53.0',
 'pg_sector_54.0',
 'pg_sector_55.0',
 'pg_sector_56.0',
 'pg_sector_61.0',
 'pg_sector_62.0',
 'pg_sector_71.0',
 'pg_sector_72.0',
 'pg_sector_81.0']]
Y = df['log_revenue']
model = sm.OLS(Y, X, missing='drop').fit()
results2_robust = model.get_robustcov_results()
print(results2_robust.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            log_revenue   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 23 Jun 2021   Prob (F-statistic):                nan
# Time:                        16:36:41   Log-Likelihood:                -2488.1
# No. Observations:                6013   AIC:                             5046.
# Df Residuals:                    5978   BIC:                             5281.
# Df Model:                          34
# Covariance Type:                  HC1
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# vio_treat_y           -0.0429      0.018     -2.369      0.018      -0.078      -0.007
# ...

# %%
#FINAL

#model 2

#treat on consumption per captia 

#we used total but also is robust to other types of consumption that could me more impacted by fear 
X = df[['vio_treat_y','lmedian_income','highschoolpc',"unemploymentrate",
"total_crimepc",'fdi','immigrantpc','selfemployedpc','totalpopulation','protestantpc','zd_estado_Baja California',
 'zd_estado_Baja California Sur',
 'zd_estado_Campeche',
 'zd_estado_Chiapas',
 'zd_estado_Chihuahua',
 'zd_estado_Coahuila de Zaragoza',
 'zd_estado_Colima',
 'zd_estado_Distrito Federal',
 'zd_estado_Durango',
 'zd_estado_Guanajuato',
 'zd_estado_Guerrero',
 'zd_estado_Hidalgo',
 'zd_estado_Jalisco',
 'zd_estado_Michoacán de Ocampo',
 'zd_estado_Morelos',
 'zd_estado_México',
 'zd_estado_Nayarit',
 'zd_estado_Nuevo León',
 'zd_estado_Oaxaca',
 'zd_estado_Puebla',
 'zd_estado_Querétaro',
 'zd_estado_Quintana Roo',
 'zd_estado_San Luis Potosí',
 'zd_estado_Sinaloa',
 'zd_estado_Sonora',
 'zd_estado_Tabasco',
 'zd_estado_Tamaulipas',
 'zd_estado_Tlaxcala',
 'zd_estado_Veracruz de Ignacio de la Llave',
 'zd_estado_Yucatán',
 'zd_estado_Zacatecas',
 'zd_zona_Semiurbano',
 'zd_zona_Urbano']]
Y = df['log_totalconsump_pc']
model = sm.OLS(Y, X, missing='drop').fit()
results2_robust = model.get_robustcov_results()
print(results2_robust.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     log_totalconsump_pc   R-squared:                       0.843
# Model:                             OLS   Adj. R-squared:                  0.842
# Method:                  Least Squares   F-statistic:                       nan
# Date:                 Wed, 23 Jun 2021   Prob (F-statistic):                nan
# Time:                         16:36:41   Log-Likelihood:                -1365.5
# No. Observations:                 6013   AIC:                             2769.
# Df Residuals:                     5994   BIC:                             2896.
# Df Model:                           18
# Covariance Type:                   HC1
# ...
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# ...

# %%
#FINAL

#model 3

#Here we control for femicide while looking at the impact of consumption on rev, we see that femicide is now not significant
X = df[['vio_treat_y','log_totalconsump_pc','lmedian_income','border','highschoolpc',"unemploymentrate","firmage",
'pg_empleados',"total_crimepc",'innovacion','immigrantpc','selfemployedpc','totalpopulation','protestantpc',
 'zd_zona_Semiurbano',
 'zd_zona_Urbano','pg_sector_11.0',
 'pg_sector_21.0',
 'pg_sector_22.0',
 'pg_sector_23.0',
 'pg_sector_31.0',
 'pg_sector_32.0',
 'pg_sector_33.0',
 'pg_sector_43.0',
 'pg_sector_46.0',
 'pg_sector_48.0',
 'pg_sector_49.0',
 'pg_sector_51.0',
 'pg_sector_52.0',
 'pg_sector_53.0',
 'pg_sector_54.0',
 'pg_sector_55.0',
 'pg_sector_56.0',
 'pg_sector_61.0',
 'pg_sector_62.0',
 'pg_sector_71.0',
 'pg_sector_72.0',
 'pg_sector_81.0']]
Y = df['log_revenue']
model = sm.OLS(Y, X, missing='drop').fit()
results2_robust = model.get_robustcov_results()
print(results2_robust.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            log_revenue   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.146
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 23 Jun 2021   Prob (F-statistic):                nan
# Time:                        16:36:41   Log-Likelihood:                -2476.9
# No. Observations:                6013   AIC:                             5026.
# Df Residuals:                    5977   BIC:                             5267.
# Df Model:                          35
# Covariance Type:                  HC1
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# vio_treat_y            -0.0180      0.019     -0.942      0.346      -0.056       0.019
# ...

# %%
#FINAL

#interact consumption with local, see that consumption helps local firms more than non local 

#model 4 
df['interaction_loc_comsump']=df['ambitooperacion_loc']*df['log_totalconsump_pc']

X = df[['interaction_loc_comsump','ambitooperacion_loc','vio_treat_y','log_totalconsump_pc','gini','lmedian_income','border','highschoolpc',"unemploymentrate","firmage",
'pg_empleados',"total_crimepc",'fdi','innovacion','immigrantpc','selfemployedpc','totalpopulation','protestantpc',
 'zd_zona_Semiurbano',
 'zd_zona_Urbano','pg_sector_11.0',
 'pg_sector_21.0',
 'pg_sector_22.0',
 'pg_sector_23.0',
 'pg_sector_31.0',
 'pg_sector_32.0',
 'pg_sector_33.0',
 'pg_sector_43.0',
 'pg_sector_46.0',
 'pg_sector_48.0',
 'pg_sector_49.0',
 'pg_sector_51.0',
 'pg_sector_52.0',
 'pg_sector_53.0',
 'pg_sector_54.0',
 'pg_sector_55.0',
 'pg_sector_56.0',
 'pg_sector_61.0',
 'pg_sector_62.0',
 'pg_sector_71.0',
 'pg_sector_72.0',
 'pg_sector_81.0']]
Y = df['log_revenue']
model = sm.OLS(Y, X, missing='drop').fit()
results2_robust = model.get_robustcov_results()
print(results2_robust.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            log_revenue   R-squared:                       0.166
# Model:                            OLS   Adj. R-squared:                  0.161
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 23 Jun 2021   Prob (F-statistic):                nan
# Time:                        16:38:24   Log-Likelihood:                -2422.4
# No. Observations:                6013   AIC:                             4925.
# Df Residuals:                    5973   BIC:                             5193.
# Df Model:                          39
# Covariance Type:                  HC1
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# interaction_loc_comsump     0.1630      0.050      3.245      0.001       0.065       0.261
# ...
